# %%
# import dependencies
from sklearn import tree
import pandas as pd
import numpy as np
import os

# %%
# read in dataset
final_full = pd.read_csv("../data/final_full.csv")

# print columns
for column in final_full.columns:
    print(column)

# preview dataset
final_full = final_full.dropna(subset = ['conference'])

final_full.head()
# Out:
# year
# player
# affiliation
# overall_pick
# position
# lane_agility
# shuttle_run
# sprint
# standing_leap
# max_leap
# bench_press
# body_fat
# hand_length
# hand_width
# height_no_shoes
# height_shoes
# reach
# weight
# wingspan
# assist_percentage
# assists
# block_percentage
# blocks
# box_plus_minus
# conference
# defensive_rebound_percentage
# defensive_rebounds
# effective_field_goal_percentage
# field_goal_attempts
# field_goals
# free_throw_attempt_rate
# free_throw_attempt
# free_throw_percentage
# free_throws
# minutes_played
# offensive_rebound_percentage
# offensive_rebounds
# personal_fouls
# points
# steal_percentage
# steals
# three_point_attempt_rate
# three_point_attempts
# three_point_percentage
# three_pointers
# total_rebound_percentage
# total_rebounds
# true_shooting_percentage
# turnover_percentage
# turnovers
# two_point_attempts
# two_point_percentage
# two_pointers
# usage_percentage
# player_id
# classification
#    year         player             affiliation  overall_pick position  \
# 1  2000    A.J. Guyton                 Indiana            32        G
# 3  2007   Aaron Brooks                  Oregon            26        G
# 5  2014   Aaron Gordon                 Arizona             4        F
# 7  2007     Aaron Gray              Pittsburgh            49        C
# 9  2018  Aaron Holiday  California-Los Angeles            23        G
#
#    lane_agility  shuttle_run  sprint  standing_leap  max_leap  ...  \
# 1         10.55         3.04    3.22           33.0      37.5  ...
# 3         10.57         3.04    3.20           32.5      39.5  ...
# 5         10.81         2.76    3.27           32.5      39.0  ...
# 7         12.07         3.10    3.70           27.0      32.5  ...
# 9         10.96         3.22    3.27           25.5      33.0  ...
#
#    total_rebounds  true_shooting_percentage  turnover_percentage  turnovers  \
# 1              90                     0.572                 12.2       69.0
# 3             149                     0.589                 14.4       89.0
# 5             303                     0.503                 10.5       55.0
# 7             341                     0.567                 11.1       55.0
# 9             121                     0.609                 18.5      125.0
#
#    two_point_attempts  two_point_percentage  two_pointers  usage_percentage  \
# 1                 272                 0.485           132               NaN
# 3                 265                 0.502           133              24.4
# 5                 337                 0.513           173              23.2
# 7                 361                 0.565           204               NaN
# 9                 255                 0.486           124              26.7
#
#          player_id  classification
# 1      aj-guyton-1         Exclude
# 3   aaron-brooks-1     Role Player
# 5   aaron-gordon-1         Starter
# 7     aaron-gray-1            Bust
# 9  aaron-holiday-1         Exclude
#
# [5 rows x 56 columns]

# %%
limit_plyrs = final_full.loc[final_full['classification'] != 'Exclude']

# limit data to '00-'14
limit_yrs = limit_plyrs.loc[final_full['year'] <= 2014]

# check distribution of classifications
limit_yrs['classification'].value_counts()
# Out:
# Role Player    156
# Starter        150
# Bust            32
# All-Star        22
# Name: classification, dtype: int64

# %%
target = limit_yrs['classification']

# drop unnecessary columns
data_clean = limit_yrs.drop(['year', 'player', 'affiliation', 'overall_pick', 'player_id', 'classification',
                            'defensive_rebounds', 'defensive_rebound_percentage', 'offensive_rebounds', 'offensive_rebound_percentage',
                            'effective_field_goal_percentage', 'field_goal_attempts', 'field_goals', 'free_throw_attempt_rate',
                            'free_throws', 'steal_percentage', 'three_point_attempt_rate', 'three_pointers', 'true_shooting_percentage',
                            'two_pointers', 'shuttle_run', 'hand_length', 'hand_width', 'height_no_shoes', 'standing_leap',
                            'weight', 'reach', 'bench_press', 'points', 'assist_percentage', 'usage_percentage'], axis = 1)

# one-hot encode position
data_clean = pd.get_dummies(data_clean, columns=['position']) 
data_clean = pd.get_dummies(data_clean, columns=['conference'])

# replace NAs with imputed values
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = np.nan, strategy = 'mean', axis = 0)

for column in data_clean.columns:
    data_clean[[column]] = imputer.fit_transform(data_clean[[column]])
    
feature_names = data_clean.columns

data_clean.head()
# Out:
# /Users/speculadora/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
#     lane_agility  sprint  max_leap  body_fat  height_shoes  wingspan  assists  \
# 3          10.57    3.20      39.5      2.70         71.75     76.00    149.0
# 5          10.81    3.27      39.0      5.05         80.75     83.75     75.0
# 7          12.07    3.70      32.5     10.80         85.75     87.25     61.0
# 19         12.15    3.37      35.5      9.10         81.75     84.75     82.0
# 21         11.96    3.16      41.0      5.80         79.00     85.00     24.0
#
#     block_percentage  blocks  box_plus_minus  ...  conference_ovc  \
# 3           0.300000     6.0        9.047368  ...             0.0
# 5           3.400000    39.0        9.600000  ...             0.0
# 7           2.863445    62.0        9.047368  ...             0.0
# 19          2.863445    70.0        9.047368  ...             0.0
# 21          2.700000    40.0        9.047368  ...             0.0
#
#     conference_pac-10  conference_pac-12  conference_patriot  conference_sec  \
# 3                 1.0                0.0                 0.0             0.0
# 5                 0.0                1.0                 0.0             0.0
# 7                 0.0                0.0                 0.0             0.0
# 19                0.0                0.0                 0.0             1.0
# 21                0.0                0.0                 0.0             0.0
#
#     conference_southern  conference_summit  conference_sun-belt  \
# 3                   0.0                0.0                  0.0
# 5                   0.0                0.0                  0.0
# 7                   0.0                0.0                  0.0
# 19                  0.0                0.0                  0.0
# 21                  0.0                0.0                  0.0
#
#     conference_wac  conference_wcc
# 3              0.0             0.0
# 5              0.0             0.0
# 7              0.0             0.0
# 19             0.0             0.0
# 21             0.0             0.0
#
# [5 rows x 52 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_clean, target, random_state = 23)
X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(limit_yrs, target, random_state = 23)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.43333333333333335

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 400)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5444444444444444

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.07130458623702082, 'steals'),
#  (0.05422731697892525, 'three_point_percentage'),
#  (0.05123943595656077, 'assists'),
#  (0.044818299181206, 'total_rebounds'),
#  (0.04454911342381298, 'blocks'),
#  (0.04314279554430592, 'minutes_played'),
#  (0.042837360173091296, 'two_point_attempts'),
#  (0.04141760278846474, 'turnovers'),
#  (0.040751363709308666, 'free_throw_percentage'),
#  (0.0404881563839969, 'two_point_percentage'),
#  (0.03878801740939531, 'free_throw_attempt'),
#  (0.03859458887906806, 'block_percentage'),
#  (0.03824847085986802, 'lane_agility'),
#  (0.03803098894314859, 'sprint'),
#  (0.03720594029342145, 'three_point_attempts'),
#  (0.036187241579422234, 'personal_fouls'),
#  (0.03581291841152049, 'body_fat'),
#  (0.03571245326041741, 'total_rebound_percentage'),
#  (0.03569328410576364, 'turnover_percentage'),
#  (0.034879784625896394, 'max_leap'),
#  (0.034837483720436324, 'wingspan'),
#  (0.031376559664424306, 'height_shoes'),
#  (0.0224303184242133, 'box_plus_minus'),
#  (0.01496195215652916, 'conference_big-12'),
#  (0.005452897331419575, 'position_F'),
#  (0.005218284570972269, 'conference_pac-10'),
#  (0.005135891407993887, 'conference_acc'),
#  (0.004721159624374401, 'conference_sec'),
#  (0.0046581720035181575, 'conference_big-ten'),
#  (0.0038019169999010064, 'position_G'),
#  (0.003801190486262084, 'conference_big-east'),
#  (0.00330569009603932, 'conference_wac'),
#  (0.0028192909199592567, 'conference_cusa'),
#  (0.0025212359730015003, 'conference_atlantic-10'),
#  (0.0023044139922650505, 'conference_pac-12'),
#  (0.001996311145412746, 'position_C'),
#  (0.0016112893391842594, 'conference_horizon'),
#  (0.0014366070124798992, 'conference_big-sky'),
#  (0.0010731341171075419, 'conference_southern'),
#  (0.0010210701310382274, 'conference_mwc'),
#  (0.00042352613943594773, 'conference_maac'),
#  (0.00035097884551808404, 'conference_wcc'),
#  (0.00018843093020618948, 'conference_sun-belt'),
#  (0.00017458186610483153, 'conference_ovc'),
#  (0.00016474760799625626, 'conference_meac'),
#  (0.00011722941074677685, 'conference_mvc'),
#  (7.973560525753385e-05, 'conference_patriot'),
#  (3.503272816722078e-05, 'conference_america-east'),
#  (2.8348344321592045e-05, 'conference_colonial'),
#  (2.2800661098533456e-05, 'conference_summit'),
#  (0.0, 'conference_mac'),
#  (0.0, 'conference_aac')]

# %%
sorted(zip(clf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.10450552746527797, 'three_point_percentage'),
#  (0.09992423244169188, 'turnover_percentage'),
#  (0.08955962171543617, 'steals'),
#  (0.07579599769867978, 'body_fat'),
#  (0.07575461906496962, 'turnovers'),
#  (0.0731894307482756, 'two_point_percentage'),
#  (0.05897727914462664, 'minutes_played'),
#  (0.054319705026059796, 'total_rebounds'),
#  (0.053290694020697964, 'personal_fouls'),
#  (0.05184671157081571, 'free_throw_percentage'),
#  (0.051542316919451936, 'assists'),
#  (0.04879020654420862, 'two_point_attempts'),
#  (0.041032762241208845, 'block_percentage'),
#  (0.033591902407223755, 'blocks'),
#  (0.01891835927940817, 'wingspan'),
#  (0.01841575212243285, 'total_rebound_percentage'),
#  (0.018381868493872713, 'conference_acc'),
#  (0.011068651996310451, 'free_throw_attempt'),
#  (0.009487415996837526, 'max_leap'),
#  (0.007906179997364607, 'position_F'),
#  (0.003700765105149401, 'lane_agility'),
#  (0.0, 'three_point_attempts'),
#  (0.0, 'sprint'),
#  (0.0, 'position_G'),
#  (0.0, 'position_C'),
#  (0.0, 'height_shoes'),
#  (0.0, 'conference_wcc'),
#  (0.0, 'conference_wac'),
#  (0.0, 'conference_sun-belt'),
#  (0.0, 'conference_summit'),
#  (0.0, 'conference_southern'),
#  (0.0, 'conference_sec'),
#  (0.0, 'conference_patriot'),
#  (0.0, 'conference_pac-12'),
#  (0.0, 'conference_pac-10'),
#  (0.0, 'conference_ovc'),
#  (0.0, 'conference_mwc'),
#  (0.0, 'conference_mvc'),
#  (0.0, 'conference_meac'),
#  (0.0, 'conference_mac'),
#  (0.0, 'conference_maac'),
#  (0.0, 'conference_horizon'),
#  (0.0, 'conference_cusa'),
#  (0.0, 'conference_colonial'),
#  (0.0, 'conference_big-ten'),
#  (0.0, 'conference_big-sky'),
#  (0.0, 'conference_big-east'),
#  (0.0, 'conference_big-12'),
#  (0.0, 'conference_atlantic-10'),
#  (0.0, 'conference_america-east'),
#  (0.0, 'conference_aac'),
#  (0.0, 'box_plus_minus')]

# %%
df = pd.DataFrame(zip(X_test_full['player'], rf.predict_proba(X_test), rf.predict(X_test)))
df2 = pd.DataFrame(zip(X_test_full['player'], clf.predict_proba(X_test), clf.predict(X_test)))

print(df[2].value_counts())
print(df2[2].value_counts())
# Out:
# Role Player    49
# Starter        39
# Bust            2
# Name: 2, dtype: int64
# Role Player    39
# Starter        34
# Bust           11
# All-Star        6
# Name: 2, dtype: int64

# %%
for index, row in df.iterrows():
    print(f'Player Name: {row[0]}')
    print(f'Model Prediction: {row[2]}')
    print(f'Probability of Bust: {row[1][1]}')
    print(f'Probability of Role Player: {row[1][2]}')
    print(f'Probability of Starter: {row[1][3]}')
    print(f'Probability of All-Star: {row[1][0]}')
    #print(f'Probability of Role Player or Better: {row[1][0] + row[1][2] + row[1][3]}')
    #print(f'Probability of Starter or Better: {row[1][0] + row[1][3]}')
    #print(f'Probability of All-Star: {row[1][0]}')
    print('----------------------------------------------')
# Out:
# Player Name: Kris Humphries
# Model Prediction: Role Player
# Probability of Bust: 0.115
# Probability of Role Player: 0.56
# Probability of Starter: 0.31
# Probability of All-Star: 0.015
# ----------------------------------------------
# Player Name: Steve Blake
# Model Prediction: Starter
# Probability of Bust: 0.1425
# Probability of Role Player: 0.3625
# Probability of Starter: 0.3775
# Probability of All-Star: 0.1175
# ----------------------------------------------
# Player Name: Mike Conley
# Model Prediction: Starter
# Probability of Bust: 0.055
# Probability of Role Player: 0.225
# Probability of Starter: 0.505
# Probability of All-Star: 0.215
# ----------------------------------------------
# Player Name: Fred Jones
# Model Prediction: Starter
# Probability of Bust: 0.06
# Probability of Role Player: 0.3575
# Probability of Starter: 0.5025
# Probability of All-Star: 0.08
# ----------------------------------------------
# Player Name: Dominic McGuire
# Model Prediction: Starter
# Probability of Bust: 0.1125
# Probability of Role Player: 0.395
# Probability of Starter: 0.44
# Probability of All-Star: 0.0525
# ----------------------------------------------
# Player Name: Danny Green
# Model Prediction: Starter
# Probability of Bust: 0.055
# Probability of Role Player: 0.28
# Probability of Starter: 0.605
# Probability of All-Star: 0.06
# ----------------------------------------------
# Player Name: T.J. Warren
# Model Prediction: Role Player
# Probability of Bust: 0.025
# Probability of Role Player: 0.5675
# Probability of Starter: 0.3425
# Probability of All-Star: 0.065
# ----------------------------------------------
# Player Name: Eric Bledsoe
# Model Prediction: Starter
# Probability of Bust: 0.0725
# Probability of Role Player: 0.395
# Probability of Starter: 0.405
# Probability of All-Star: 0.1275
# ----------------------------------------------
# Player Name: Kawhi Leonard
# Model Prediction: Starter
# Probability of Bust: 0.015
# Probability of Role Player: 0.43
# Probability of Starter: 0.4775
# Probability of All-Star: 0.0775
# ----------------------------------------------
# Player Name: Ronny Turiaf
# Model Prediction: Role Player
# Probability of Bust: 0.0525
# Probability of Role Player: 0.5925
# Probability of Starter: 0.3125
# Probability of All-Star: 0.0425
# ----------------------------------------------
# Player Name: Andrew Wiggins
# Model Prediction: Role Player
# Probability of Bust: 0.0225
# Probability of Role Player: 0.7625
# Probability of Starter: 0.2025
# Probability of All-Star: 0.0125
# ----------------------------------------------
# Player Name: Evan Turner
# Model Prediction: Starter
# Probability of Bust: 0.02
# Probability of Role Player: 0.3575
# Probability of Starter: 0.465
# Probability of All-Star: 0.1575
# ----------------------------------------------
# Player Name: Jamaal Tinsley
# Model Prediction: Starter
# Probability of Bust: 0.1275
# Probability of Role Player: 0.3325
# Probability of Starter: 0.44
# Probability of All-Star: 0.1
# ----------------------------------------------
# Player Name: Chris Kaman
# Model Prediction: Role Player
# Probability of Bust: 0.16
# Probability of Role Player: 0.46
# Probability of Starter: 0.33
# Probability of All-Star: 0.05
# ----------------------------------------------
# Player Name: Keyon Dooling
# Model Prediction: Bust
# Probability of Bust: 0.8675
# Probability of Role Player: 0.0675
# Probability of Starter: 0.0625
# Probability of All-Star: 0.0025
# ----------------------------------------------
# Player Name: Gilbert Arenas
# Model Prediction: Starter
# Probability of Bust: 0.07
# Probability of Role Player: 0.3275
# Probability of Starter: 0.5125
# Probability of All-Star: 0.09
# ----------------------------------------------
# Player Name: James Jones
# Model Prediction: Role Player
# Probability of Bust: 0.0425
# Probability of Role Player: 0.5225
# Probability of Starter: 0.415
# Probability of All-Star: 0.02
# ----------------------------------------------
# Player Name: Darrell Arthur
# Model Prediction: Role Player
# Probability of Bust: 0.155
# Probability of Role Player: 0.565
# Probability of Starter: 0.27
# Probability of All-Star: 0.01
# ----------------------------------------------
# Player Name: Jerami Grant
# Model Prediction: Role Player
# Probability of Bust: 0.065
# Probability of Role Player: 0.6525
# Probability of Starter: 0.265
# Probability of All-Star: 0.0175
# ----------------------------------------------
# Player Name: Jeff Ayres
# Model Prediction: Role Player
# Probability of Bust: 0.1175
# Probability of Role Player: 0.4825
# Probability of Starter: 0.3375
# Probability of All-Star: 0.0625
# ----------------------------------------------
# Player Name: Melvin Ely
# Model Prediction: Role Player
# Probability of Bust: 0.0925
# Probability of Role Player: 0.55
# Probability of Starter: 0.345
# Probability of All-Star: 0.0125
# ----------------------------------------------
# Player Name: Stromile Swift
# Model Prediction: Starter
# Probability of Bust: 0.01
# Probability of Role Player: 0.09
# Probability of Starter: 0.8875
# Probability of All-Star: 0.0125
# ----------------------------------------------
# Player Name: Rodney Carney
# Model Prediction: Starter
# Probability of Bust: 0.11
# Probability of Role Player: 0.365
# Probability of Starter: 0.4675
# Probability of All-Star: 0.0575
# ----------------------------------------------
# Player Name: Richard Jefferson
# Model Prediction: Role Player
# Probability of Bust: 0.0675
# Probability of Role Player: 0.4825
# Probability of Starter: 0.405
# Probability of All-Star: 0.045
# ----------------------------------------------
# Player Name: Marcus Thornton
# Model Prediction: Starter
# Probability of Bust: 0.09
# Probability of Role Player: 0.255
# Probability of Starter: 0.5275
# Probability of All-Star: 0.1275
# ----------------------------------------------
# Player Name: James Anderson
# Model Prediction: Role Player
# Probability of Bust: 0.0725
# Probability of Role Player: 0.4825
# Probability of Starter: 0.385
# Probability of All-Star: 0.06
# ----------------------------------------------
# Player Name: Matt Barnes
# Model Prediction: Role Player
# Probability of Bust: 0.095
# Probability of Role Player: 0.4475
# Probability of Starter: 0.4125
# Probability of All-Star: 0.045
# ----------------------------------------------
# Player Name: Marcus Fizer
# Model Prediction: Role Player
# Probability of Bust: 0.0025
# Probability of Role Player: 0.9875
# Probability of Starter: 0.01
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Nick Young
# Model Prediction: Role Player
# Probability of Bust: 0.1525
# Probability of Role Player: 0.565
# Probability of Starter: 0.235
# Probability of All-Star: 0.0475
# ----------------------------------------------
# Player Name: Jamal Crawford
# Model Prediction: Starter
# Probability of Bust: 0.015
# Probability of Role Player: 0.0525
# Probability of Starter: 0.93
# Probability of All-Star: 0.0025
# ----------------------------------------------
# Player Name: Robert Sacre
# Model Prediction: Role Player
# Probability of Bust: 0.1675
# Probability of Role Player: 0.635
# Probability of Starter: 0.18
# Probability of All-Star: 0.0175
# ----------------------------------------------
# Player Name: Bradley Beal
# Model Prediction: Starter
# Probability of Bust: 0.05
# Probability of Role Player: 0.3
# Probability of Starter: 0.57
# Probability of All-Star: 0.08
# ----------------------------------------------
# Player Name: Michael Kidd-Gilchrist
# Model Prediction: Starter
# Probability of Bust: 0.0125
# Probability of Role Player: 0.405
# Probability of Starter: 0.5425
# Probability of All-Star: 0.04
# ----------------------------------------------
# Player Name: Carl Landry
# Model Prediction: Role Player
# Probability of Bust: 0.0275
# Probability of Role Player: 0.5975
# Probability of Starter: 0.35
# Probability of All-Star: 0.025
# ----------------------------------------------
# Player Name: Travis Diener
# Model Prediction: Role Player
# Probability of Bust: 0.1025
# Probability of Role Player: 0.47
# Probability of Starter: 0.365
# Probability of All-Star: 0.0625
# ----------------------------------------------
# Player Name: Sam Young
# Model Prediction: Role Player
# Probability of Bust: 0.015
# Probability of Role Player: 0.7725
# Probability of Starter: 0.2
# Probability of All-Star: 0.0125
# ----------------------------------------------
# Player Name: Joey Dorsey
# Model Prediction: Starter
# Probability of Bust: 0.1
# Probability of Role Player: 0.3425
# Probability of Starter: 0.505
# Probability of All-Star: 0.0525
# ----------------------------------------------
# Player Name: Willie Green
# Model Prediction: Role Player
# Probability of Bust: 0.1
# Probability of Role Player: 0.565
# Probability of Starter: 0.3125
# Probability of All-Star: 0.0225
# ----------------------------------------------
# Player Name: Josh Childress
# Model Prediction: Role Player
# Probability of Bust: 0.1175
# Probability of Role Player: 0.59
# Probability of Starter: 0.2775
# Probability of All-Star: 0.015
# ----------------------------------------------
# Player Name: Kevin Love
# Model Prediction: Role Player
# Probability of Bust: 0.015
# Probability of Role Player: 0.575
# Probability of Starter: 0.3025
# Probability of All-Star: 0.1075
# ----------------------------------------------
# Player Name: Stromile Swift
# Model Prediction: Starter
# Probability of Bust: 0.01
# Probability of Role Player: 0.09
# Probability of Starter: 0.8875
# Probability of All-Star: 0.0125
# ----------------------------------------------
# Player Name: Kemba Walker
# Model Prediction: Starter
# Probability of Bust: 0.15
# Probability of Role Player: 0.3
# Probability of Starter: 0.355
# Probability of All-Star: 0.195
# ----------------------------------------------
# Player Name: Aaron Gray
# Model Prediction: Role Player
# Probability of Bust: 0.1
# Probability of Role Player: 0.495
# Probability of Starter: 0.3825
# Probability of All-Star: 0.0225
# ----------------------------------------------
# Player Name: Tayshaun Prince
# Model Prediction: Role Player
# Probability of Bust: 0.045
# Probability of Role Player: 0.5575
# Probability of Starter: 0.3875
# Probability of All-Star: 0.01
# ----------------------------------------------
# Player Name: Jared Dudley
# Model Prediction: Role Player
# Probability of Bust: 0.0625
# Probability of Role Player: 0.4825
# Probability of Starter: 0.4175
# Probability of All-Star: 0.0375
# ----------------------------------------------
# Player Name: Glen Davis
# Model Prediction: Role Player
# Probability of Bust: 0.085
# Probability of Role Player: 0.5475
# Probability of Starter: 0.3525
# Probability of All-Star: 0.015
# ----------------------------------------------
# Player Name: Arron Afflalo
# Model Prediction: Starter
# Probability of Bust: 0.12
# Probability of Role Player: 0.4225
# Probability of Starter: 0.435
# Probability of All-Star: 0.0225
# ----------------------------------------------
# Player Name: Tristan Thompson
# Model Prediction: Role Player
# Probability of Bust: 0.0625
# Probability of Role Player: 0.5025
# Probability of Starter: 0.42
# Probability of All-Star: 0.015
# ----------------------------------------------
# Player Name: Wayne Ellington
# Model Prediction: Starter
# Probability of Bust: 0.085
# Probability of Role Player: 0.4275
# Probability of Starter: 0.435
# Probability of All-Star: 0.0525
# ----------------------------------------------
# Player Name: Courtney Alexander
# Model Prediction: Bust
# Probability of Bust: 0.68
# Probability of Role Player: 0.1575
# Probability of Starter: 0.155
# Probability of All-Star: 0.0075
# ----------------------------------------------
# Player Name: Brandon Bass
# Model Prediction: Role Player
# Probability of Bust: 0.1875
# Probability of Role Player: 0.5675
# Probability of Starter: 0.2325
# Probability of All-Star: 0.0125
# ----------------------------------------------
# Player Name: Shabazz Napier
# Model Prediction: Starter
# Probability of Bust: 0.0825
# Probability of Role Player: 0.3125
# Probability of Starter: 0.395
# Probability of All-Star: 0.21
# ----------------------------------------------
# Player Name: Michael Carter-Williams
# Model Prediction: Starter
# Probability of Bust: 0.08
# Probability of Role Player: 0.2825
# Probability of Starter: 0.465
# Probability of All-Star: 0.1725
# ----------------------------------------------
# Player Name: Stromile Swift
# Model Prediction: Starter
# Probability of Bust: 0.01
# Probability of Role Player: 0.09
# Probability of Starter: 0.8875
# Probability of All-Star: 0.0125
# ----------------------------------------------
# Player Name: Morris Peterson
# Model Prediction: Role Player
# Probability of Bust: 0.085
# Probability of Role Player: 0.4525
# Probability of Starter: 0.41
# Probability of All-Star: 0.0525
# ----------------------------------------------
# Player Name: Mike Muscala
# Model Prediction: Starter
# Probability of Bust: 0.07
# Probability of Role Player: 0.2825
# Probability of Starter: 0.595
# Probability of All-Star: 0.0525
# ----------------------------------------------
# Player Name: Mike Miller
# Model Prediction: Starter
# Probability of Bust: 0.0025
# Probability of Role Player: 0.0275
# Probability of Starter: 0.9675
# Probability of All-Star: 0.0025
# ----------------------------------------------
# Player Name: P.J. Tucker
# Model Prediction: Starter
# Probability of Bust: 0.1075
# Probability of Role Player: 0.3675
# Probability of Starter: 0.395
# Probability of All-Star: 0.13
# ----------------------------------------------
# Player Name: John Henson
# Model Prediction: Starter
# Probability of Bust: 0.0875
# Probability of Role Player: 0.3125
# Probability of Starter: 0.555
# Probability of All-Star: 0.045
# ----------------------------------------------
# Player Name: Mario Chalmers
# Model Prediction: Starter
# Probability of Bust: 0.2375
# Probability of Role Player: 0.235
# Probability of Starter: 0.4425
# Probability of All-Star: 0.085
# ----------------------------------------------
# Player Name: Marreese Speights
# Model Prediction: Role Player
# Probability of Bust: 0.0875
# Probability of Role Player: 0.7475
# Probability of Starter: 0.1575
# Probability of All-Star: 0.0075
# ----------------------------------------------
# Player Name: Khris Middleton
# Model Prediction: Role Player
# Probability of Bust: 0.1225
# Probability of Role Player: 0.5375
# Probability of Starter: 0.3325
# Probability of All-Star: 0.0075
# ----------------------------------------------
# Player Name: Chandler Parsons
# Model Prediction: Role Player
# Probability of Bust: 0.07
# Probability of Role Player: 0.4875
# Probability of Starter: 0.38
# Probability of All-Star: 0.0625
# ----------------------------------------------
# Player Name: T.J. Ford
# Model Prediction: Starter
# Probability of Bust: 0.1175
# Probability of Role Player: 0.305
# Probability of Starter: 0.48
# Probability of All-Star: 0.0975
# ----------------------------------------------
# Player Name: Charlie Villanueva
# Model Prediction: Role Player
# Probability of Bust: 0.1375
# Probability of Role Player: 0.5
# Probability of Starter: 0.3575
# Probability of All-Star: 0.005
# ----------------------------------------------
# Player Name: Quentin Richardson
# Model Prediction: Role Player
# Probability of Bust: 0.075
# Probability of Role Player: 0.56
# Probability of Starter: 0.305
# Probability of All-Star: 0.06
# ----------------------------------------------
# Player Name: Darren Collison
# Model Prediction: Role Player
# Probability of Bust: 0.05
# Probability of Role Player: 0.4625
# Probability of Starter: 0.3675
# Probability of All-Star: 0.12
# ----------------------------------------------
# Player Name: Delonte West
# Model Prediction: Starter
# Probability of Bust: 0.065
# Probability of Role Player: 0.365
# Probability of Starter: 0.46
# Probability of All-Star: 0.11
# ----------------------------------------------
# Player Name: Joel Embiid
# Model Prediction: Starter
# Probability of Bust: 0.1825
# Probability of Role Player: 0.2975
# Probability of Starter: 0.4825
# Probability of All-Star: 0.0375
# ----------------------------------------------
# Player Name: Jameer Nelson
# Model Prediction: Role Player
# Probability of Bust: 0.09
# Probability of Role Player: 0.4175
# Probability of Starter: 0.395
# Probability of All-Star: 0.0975
# ----------------------------------------------
# Player Name: Meyers Leonard
# Model Prediction: Role Player
# Probability of Bust: 0.11
# Probability of Role Player: 0.4925
# Probability of Starter: 0.3875
# Probability of All-Star: 0.01
# ----------------------------------------------
# Player Name: E'Twaun Moore
# Model Prediction: Role Player
# Probability of Bust: 0.08
# Probability of Role Player: 0.585
# Probability of Starter: 0.2825
# Probability of All-Star: 0.0525
# ----------------------------------------------
# Player Name: Chase Budinger
# Model Prediction: Role Player
# Probability of Bust: 0.04
# Probability of Role Player: 0.575
# Probability of Starter: 0.285
# Probability of All-Star: 0.1
# ----------------------------------------------
# Player Name: Reggie Jackson
# Model Prediction: Role Player
# Probability of Bust: 0.1175
# Probability of Role Player: 0.4775
# Probability of Starter: 0.3625
# Probability of All-Star: 0.0425
# ----------------------------------------------
# Player Name: Tobias Harris
# Model Prediction: Role Player
# Probability of Bust: 0.0275
# Probability of Role Player: 0.73
# Probability of Starter: 0.2275
# Probability of All-Star: 0.015
# ----------------------------------------------
# Player Name: Ty Lawson
# Model Prediction: Starter
# Probability of Bust: 0.07
# Probability of Role Player: 0.3225
# Probability of Starter: 0.46
# Probability of All-Star: 0.1475
# ----------------------------------------------
# Player Name: Cory Joseph
# Model Prediction: Role Player
# Probability of Bust: 0.1725
# Probability of Role Player: 0.4875
# Probability of Starter: 0.2875
# Probability of All-Star: 0.0525
# ----------------------------------------------
# Player Name: Brandon Roy
# Model Prediction: Role Player
# Probability of Bust: 0.105
# Probability of Role Player: 0.4875
# Probability of Starter: 0.315
# Probability of All-Star: 0.0925
# ----------------------------------------------
# Player Name: Ekpe Udoh
# Model Prediction: Starter
# Probability of Bust: 0.085
# Probability of Role Player: 0.2875
# Probability of Starter: 0.57
# Probability of All-Star: 0.0575
# ----------------------------------------------
# Player Name: Channing Frye
# Model Prediction: Role Player
# Probability of Bust: 0.03
# Probability of Role Player: 0.5575
# Probability of Starter: 0.39
# Probability of All-Star: 0.0225
# ----------------------------------------------
# Player Name: Isaiah Thomas
# Model Prediction: Role Player
# Probability of Bust: 0.035
# Probability of Role Player: 0.43
# Probability of Starter: 0.405
# Probability of All-Star: 0.13
# ----------------------------------------------
# Player Name: Courtney Lee
# Model Prediction: Role Player
# Probability of Bust: 0.08
# Probability of Role Player: 0.4625
# Probability of Starter: 0.405
# Probability of All-Star: 0.0525
# ----------------------------------------------
# Player Name: David Harrison
# Model Prediction: Role Player
# Probability of Bust: 0.2025
# Probability of Role Player: 0.5775
# Probability of Starter: 0.2075
# Probability of All-Star: 0.0125
# ----------------------------------------------
# Player Name: Raymond Felton
# Model Prediction: Starter
# Probability of Bust: 0.0425
# Probability of Role Player: 0.2525
# Probability of Starter: 0.49
# Probability of All-Star: 0.215
# ----------------------------------------------
# Player Name: Iman Shumpert
# Model Prediction: Starter
# Probability of Bust: 0.105
# Probability of Role Player: 0.2675
# Probability of Starter: 0.5525
# Probability of All-Star: 0.075
# ----------------------------------------------
# Player Name: Renaldo Balkman
# Model Prediction: Starter
# Probability of Bust: 0.0225
# Probability of Role Player: 0.2425
# Probability of Starter: 0.6775
# Probability of All-Star: 0.0575
# ----------------------------------------------
# Player Name: Xavier Henry
# Model Prediction: Starter
# Probability of Bust: 0.1825
# Probability of Role Player: 0.265
# Probability of Starter: 0.525
# Probability of All-Star: 0.0275
# ----------------------------------------------
# Player Name: Eric Maynor
# Model Prediction: Starter
# Probability of Bust: 0.045
# Probability of Role Player: 0.3275
# Probability of Starter: 0.475
# Probability of All-Star: 0.1525
# ----------------------------------------------
# Player Name: Lance Stephenson
# Model Prediction: Role Player
# Probability of Bust: 0.0425
# Probability of Role Player: 0.6475
# Probability of Starter: 0.2875
# Probability of All-Star: 0.0225
# ----------------------------------------------
# Player Name: Desmond Mason
# Model Prediction: Role Player
# Probability of Bust: 0.0225
# Probability of Role Player: 0.8475
# Probability of Starter: 0.1225
# Probability of All-Star: 0.0075
# ----------------------------------------------

# %%
for index, row in df2.iterrows():
    print(f'Player Name: {row[0]}')
    print(f'Model Prediction: {row[2]}')
    print(f'Probability of Bust: {row[1][1]}')
    print(f'Probability of Role Player: {row[1][2]}')
    print(f'Probability of Starter: {row[1][3]}')
    print(f'Probability of All-Star: {row[1][0]}')
    #print(f'Probability of Role Player or Better: {row[1][0] + row[1][2] + row[1][3]}')
    #print(f'Probability of Starter or Better: {row[1][0] + row[1][3]}')
    #print(f'Probability of All-Star: {row[1][0]}')
    print('----------------------------------------------')
# Out:
# Player Name: Kris Humphries
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Steve Blake
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Mike Conley
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Fred Jones
# Model Prediction: All-Star
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 1.0
# ----------------------------------------------
# Player Name: Dominic McGuire
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Danny Green
# Model Prediction: All-Star
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 1.0
# ----------------------------------------------
# Player Name: T.J. Warren
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Eric Bledsoe
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Kawhi Leonard
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Ronny Turiaf
# Model Prediction: All-Star
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 1.0
# ----------------------------------------------
# Player Name: Andrew Wiggins
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Evan Turner
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Jamaal Tinsley
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Chris Kaman
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Keyon Dooling
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Gilbert Arenas
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: James Jones
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Darrell Arthur
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Jerami Grant
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Jeff Ayres
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Melvin Ely
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Stromile Swift
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Rodney Carney
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Richard Jefferson
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Marcus Thornton
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: James Anderson
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Matt Barnes
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Marcus Fizer
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Nick Young
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Jamal Crawford
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Robert Sacre
# Model Prediction: All-Star
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 1.0
# ----------------------------------------------
# Player Name: Bradley Beal
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Michael Kidd-Gilchrist
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Carl Landry
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Travis Diener
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Sam Young
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Joey Dorsey
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Willie Green
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Josh Childress
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Kevin Love
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Stromile Swift
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Kemba Walker
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Aaron Gray
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Tayshaun Prince
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Jared Dudley
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Glen Davis
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Arron Afflalo
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Tristan Thompson
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Wayne Ellington
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Courtney Alexander
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Brandon Bass
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Shabazz Napier
# Model Prediction: All-Star
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 1.0
# ----------------------------------------------
# Player Name: Michael Carter-Williams
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Stromile Swift
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Morris Peterson
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Mike Muscala
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Mike Miller
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: P.J. Tucker
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: John Henson
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Mario Chalmers
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Marreese Speights
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Khris Middleton
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Chandler Parsons
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: T.J. Ford
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Charlie Villanueva
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Quentin Richardson
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Darren Collison
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Delonte West
# Model Prediction: All-Star
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 1.0
# ----------------------------------------------
# Player Name: Joel Embiid
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Jameer Nelson
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Meyers Leonard
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: E'Twaun Moore
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Chase Budinger
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Reggie Jackson
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Tobias Harris
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Ty Lawson
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Cory Joseph
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Brandon Roy
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Ekpe Udoh
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Channing Frye
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Isaiah Thomas
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Courtney Lee
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: David Harrison
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Raymond Felton
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Iman Shumpert
# Model Prediction: Bust
# Probability of Bust: 1.0
# Probability of Role Player: 0.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Renaldo Balkman
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Xavier Henry
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Eric Maynor
# Model Prediction: Starter
# Probability of Bust: 0.0
# Probability of Role Player: 0.0
# Probability of Starter: 1.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Lance Stephenson
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
# Player Name: Desmond Mason
# Model Prediction: Role Player
# Probability of Bust: 0.0
# Probability of Role Player: 1.0
# Probability of Starter: 0.0
# Probability of All-Star: 0.0
# ----------------------------------------------
