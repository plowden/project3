# %%
# import dependencies
from sklearn import tree
import pandas as pd
import numpy as np
import os

# %%
# read in dataset
final_full = pd.read_csv("../data/final_full.csv")

# print columns
for column in final_full.columns:
    print(column)

# preview dataset
final_full.head()
# Out:
# year
# player
# affiliation
# overall_pick
# position
# lane_agility
# shuttle_run
# sprint
# standing_leap
# max_leap
# bench_press
# body_fat
# hand_length
# hand_width
# height_no_shoes
# height_shoes
# reach
# weight
# wingspan
# classification
# assist_percentage
# assists
# block_percentage
# blocks
# defensive_rebound_percentage
# defensive_rebounds
# effective_field_goal_percentage
# field_goal_attempts
# field_goals
# free_throw_attempt_rate
# free_throw_attempt
# free_throw_percentage
# free_throws
# minutes_played
# offensive_rebound_percentage
# offensive_rebounds
# personal_fouls
# points
# steal_percentage
# steals
# three_point_attempt_rate
# three_point_attempts
# three_point_percentage
# three_pointers
# total_rebound_percentage
# total_rebounds
# true_shooting_percentage
# turnover_percentage
# turnovers
# two_point_attempts
# two_point_percentage
# two_pointers
# usage_percentage
# player_id
# classification.1
#    year         player             affiliation  overall_pick position  \
# 0  2000    A.J. Guyton                 Indiana            32        G
# 1  2007   Aaron Brooks                  Oregon            26        G
# 2  2014   Aaron Gordon                 Arizona             4        F
# 3  2007     Aaron Gray              Pittsburgh            49        C
# 4  2018  Aaron Holiday  California-Los Angeles            23        G
#
#    lane_agility  shuttle_run  sprint  standing_leap  max_leap  ...  \
# 0         10.55         3.04    3.22           33.0      37.5  ...
# 1         10.57         3.04    3.20           32.5      39.5  ...
# 2         10.81         2.76    3.27           32.5      39.0  ...
# 3         12.07         3.10    3.70           27.0      32.5  ...
# 4         10.96         3.22    3.27           25.5      33.0  ...
#
#    total_rebounds  true_shooting_percentage  turnover_percentage  turnovers  \
# 0             429                     0.572                 13.6      218.0
# 1             397                     0.565                 18.5      303.0
# 2             303                     0.503                 10.5       55.0
# 3             790                     0.565                 15.2      176.0
# 4             320                     0.580                 19.6      304.0
#
#    two_point_attempts  two_point_percentage  two_pointers  usage_percentage  \
# 0                 958                 0.484           464               NaN
# 1                 616                 0.479           295              23.2
# 2                 337                 0.513           173              23.2
# 3                 789                 0.550           434              24.9
# 4                 631                 0.469           296              23.3
#
#          player_id classification.1
# 0      aj-guyton-1             Bust
# 1   aaron-brooks-1      Role Player
# 2   aaron-gordon-1             Bust
# 3     aaron-gray-1             Bust
# 4  aaron-holiday-1             Bust
#
# [5 rows x 55 columns]

# %%
# limit data to '00-'14
limit_yrs = final_full.loc[final_full['year'] <= 2014]

limit_yrs.head()
# Out:
#    year        player affiliation  overall_pick position  lane_agility  \
# 0  2000   A.J. Guyton     Indiana            32        G         10.55
# 1  2007  Aaron Brooks      Oregon            26        G         10.57
# 2  2014  Aaron Gordon     Arizona             4        F         10.81
# 3  2007    Aaron Gray  Pittsburgh            49        C         12.07
# 6  2007      Acie Law   Texas A&M            11        G         11.00
#
#    shuttle_run  sprint  standing_leap  max_leap  ...  total_rebounds  \
# 0         3.04    3.22           33.0      37.5  ...             429
# 1         3.04    3.20           32.5      39.5  ...             397
# 2         2.76    3.27           32.5      39.0  ...             303
# 3         3.10    3.70           27.0      32.5  ...             790
# 6         3.04    3.22           29.0      34.0  ...             379
#
#    true_shooting_percentage  turnover_percentage  turnovers  \
# 0                     0.572                 13.6      218.0
# 1                     0.565                 18.5      303.0
# 2                     0.503                 10.5       55.0
# 3                     0.565                 15.2      176.0
# 6                     0.551                 16.5      299.0
#
#    two_point_attempts  two_point_percentage  two_pointers  usage_percentage  \
# 0                 958                 0.484           464               NaN
# 1                 616                 0.479           295              23.2
# 2                 337                 0.513           173              23.2
# 3                 789                 0.550           434              24.9
# 6                 979                 0.502           491              25.3
#
#         player_id classification.1
# 0     aj-guyton-1             Bust
# 1  aaron-brooks-1      Role Player
# 2  aaron-gordon-1             Bust
# 3    aaron-gray-1             Bust
# 6      acie-law-1             Bust
#
# [5 rows x 55 columns]

# %%
target = limit_yrs['classification']

# drop unnecessary columns
data_clean = limit_yrs.drop(['year', 'affiliation', 'position', 'player', 'overall_pick', 'player_id', 'classification', 'classification.1'], axis = 1)

# replace NAs with imputed values
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = np.nan, strategy = 'mean', axis = 0)

for column in data_clean.columns:
    data_clean[[column]] = imputer.fit_transform(data_clean[[column]])
    
feature_names = data_clean.columns

data_clean.head()
# Out:
# /Users/speculadora/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
#    lane_agility  shuttle_run  sprint  standing_leap  max_leap  bench_press  \
# 0         10.55         3.04    3.22           33.0      37.5         9.00
# 1         10.57         3.04    3.20           32.5      39.5         6.00
# 2         10.81         2.76    3.27           32.5      39.0        11.36
# 3         12.07         3.10    3.70           27.0      32.5        17.00
# 6         11.00         3.04    3.22           29.0      34.0         8.00
#
#    body_fat  hand_length  hand_width  height_no_shoes  ...  three_pointers  \
# 0      6.39         8.46        9.10            72.75  ...           283.0
# 1      2.70         8.46        9.10            70.00  ...           205.0
# 2      5.05         8.75       10.50            79.50  ...            16.0
# 3     10.80         9.12        9.86            84.00  ...             0.0
# 6      5.60         8.46        9.10            74.00  ...           114.0
#
#    total_rebound_percentage  total_rebounds  true_shooting_percentage  \
# 0                 11.727473           429.0                     0.572
# 1                  6.600000           397.0                     0.565
# 2                 14.900000           303.0                     0.503
# 3                 19.400000           790.0                     0.565
# 6                  5.700000           379.0                     0.551
#
#    turnover_percentage  turnovers  two_point_attempts  two_point_percentage  \
# 0                 13.6      218.0               958.0                 0.484
# 1                 18.5      303.0               616.0                 0.479
# 2                 10.5       55.0               337.0                 0.513
# 3                 15.2      176.0               789.0                 0.550
# 6                 16.5      299.0               979.0                 0.502
#
#    two_pointers  usage_percentage
# 0         464.0         24.178242
# 1         295.0         23.200000
# 2         173.0         23.200000
# 3         434.0         24.900000
# 6         491.0         25.300000
#
# [5 rows x 47 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_clean, target, random_state = 23)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.3706293706293706

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.6293706293706294

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.03429112419217804, 'two_point_percentage'),
#  (0.03326438077993949, 'true_shooting_percentage'),
#  (0.031248560592973026, 'assist_percentage'),
#  (0.030586039488825194, 'effective_field_goal_percentage'),
#  (0.029522432417779746, 'body_fat'),
#  (0.028446994723412732, 'sprint'),
#  (0.027989451949257026, 'assists'),
#  (0.02762887620123358, 'steals'),
#  (0.02741794463363741, 'free_throw_percentage'),
#  (0.025669472194958628, 'offensive_rebounds'),
#  (0.025555187254266334, 'total_rebounds'),
#  (0.02539043173228403, 'free_throw_attempt_rate'),
#  (0.023944462215830443, 'turnovers'),
#  (0.02388013683918207, 'blocks'),
#  (0.0235108578104738, 'total_rebound_percentage'),
#  (0.023433319980043527, 'free_throws'),
#  (0.023184781327415527, 'turnover_percentage'),
#  (0.02288362663252971, 'minutes_played'),
#  (0.022493715468976314, 'three_point_attempts'),
#  (0.02241905387269148, 'weight'),
#  (0.021640331382047906, 'defensive_rebounds'),
#  (0.02160249446595056, 'three_point_percentage'),
#  (0.021283921695983574, 'three_pointers'),
#  (0.02098007895163407, 'wingspan'),
#  (0.020739300050221822, 'three_point_attempt_rate'),
#  (0.020674428047969734, 'lane_agility'),
#  (0.020651049102669745, 'two_point_attempts'),
#  (0.020510224222052936, 'usage_percentage'),
#  (0.020083152497047774, 'free_throw_attempt'),
#  (0.019775514785990107, 'two_pointers'),
#  (0.019732764461876835, 'field_goal_attempts'),
#  (0.01952599620857977, 'personal_fouls'),
#  (0.0195197617963879, 'field_goals'),
#  (0.019276263241346753, 'max_leap'),
#  (0.01849399433383614, 'height_no_shoes'),
#  (0.017560128468068148, 'bench_press'),
#  (0.017226904929051618, 'standing_leap'),
#  (0.01700748319174634, 'points'),
#  (0.0167119779533419, 'reach'),
#  (0.01638062676933843, 'block_percentage'),
#  (0.01633788384939406, 'steal_percentage'),
#  (0.015344875902652674, 'height_shoes'),
#  (0.01379387845633252, 'offensive_rebound_percentage'),
#  (0.013206410658288818, 'defensive_rebound_percentage'),
#  (0.008320410356881447, 'hand_width'),
#  (0.00796389902059394, 'hand_length'),
#  (0.0028953948928261896, 'shuttle_run')]
