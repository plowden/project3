# %%
# import dependencies
from sklearn import tree
import pandas as pd
import numpy as np
import os

# %%
# read in dataset
final_full = pd.read_csv("../data/final_full.csv")

# print columns
for column in final_full.columns:
    print(column)

# preview dataset
final_full.head()
# Out:
# year
# player
# affiliation
# overall_pick
# position
# lane_agility
# shuttle_run
# sprint
# standing_leap
# max_leap
# bench_press
# body_fat
# hand_length
# hand_width
# height_no_shoes
# height_shoes
# reach
# weight
# wingspan
# classification
# assist_percentage
# assists
# block_percentage
# blocks
# defensive_rebound_percentage
# defensive_rebounds
# effective_field_goal_percentage
# field_goal_attempts
# field_goals
# free_throw_attempt_rate
# free_throw_attempt
# free_throw_percentage
# free_throws
# minutes_played
# offensive_rebound_percentage
# offensive_rebounds
# personal_fouls
# points
# steal_percentage
# steals
# three_point_attempt_rate
# three_point_attempts
# three_point_percentage
# three_pointers
# total_rebound_percentage
# total_rebounds
# true_shooting_percentage
# turnover_percentage
# turnovers
# two_point_attempts
# two_point_percentage
# two_pointers
# usage_percentage
# player_id
# classification.1
#    year         player             affiliation  overall_pick position  \
# 0  2000    A.J. Guyton                 Indiana            32        G
# 1  2007   Aaron Brooks                  Oregon            26        G
# 2  2014   Aaron Gordon                 Arizona             4        F
# 3  2007     Aaron Gray              Pittsburgh            49        C
# 4  2018  Aaron Holiday  California-Los Angeles            23        G
#
#    lane_agility  shuttle_run  sprint  standing_leap  max_leap  ...  \
# 0         10.55         3.04    3.22           33.0      37.5  ...
# 1         10.57         3.04    3.20           32.5      39.5  ...
# 2         10.81         2.76    3.27           32.5      39.0  ...
# 3         12.07         3.10    3.70           27.0      32.5  ...
# 4         10.96         3.22    3.27           25.5      33.0  ...
#
#    total_rebounds  true_shooting_percentage  turnover_percentage  turnovers  \
# 0             429                     0.572                 13.6      218.0
# 1             397                     0.565                 18.5      303.0
# 2             303                     0.503                 10.5       55.0
# 3             790                     0.565                 15.2      176.0
# 4             320                     0.580                 19.6      304.0
#
#    two_point_attempts  two_point_percentage  two_pointers  usage_percentage  \
# 0                 958                 0.484           464               NaN
# 1                 616                 0.479           295              23.2
# 2                 337                 0.513           173              23.2
# 3                 789                 0.550           434              24.9
# 4                 631                 0.469           296              23.3
#
#          player_id classification.1
# 0      aj-guyton-1          Exclude
# 1   aaron-brooks-1          Starter
# 2   aaron-gordon-1          Starter
# 3     aaron-gray-1             Bust
# 4  aaron-holiday-1          Exclude
#
# [5 rows x 55 columns]

# %%
limit_plyrs = final_full.loc[final_full['classification'] != 'Exclude']

# limit data to '00-'14
limit_yrs = limit_plyrs.loc[final_full['year'] <= 2014]

# check distribution of classifications
limit_yrs['classification'].value_counts()
# Out:
# Role Player    152
# Starter         92
# All-Star        67
# Bust            56
# Name: classification, dtype: int64

# %%
target = limit_yrs['classification']

# drop unnecessary columns
data_clean = limit_yrs.drop(['year', 'affiliation', 'player', 'position', 'overall_pick', 'player_id',
                             'classification', 'classification.1'], axis = 1)

# one-hot encode position
# data_clean = pd.get_dummies(data_clean, columns=['position']) 

# replace NAs with imputed values
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = np.nan, strategy = 'mean', axis = 0)

for column in data_clean.columns:
    data_clean[[column]] = imputer.fit_transform(data_clean[[column]])
    
feature_names = data_clean.columns

data_clean.head()
# Out:
# /Users/speculadora/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
#    lane_agility  sprint  standing_leap  max_leap  bench_press  body_fat  \
# 1         10.57    3.20           32.5      39.5         6.00      2.70
# 2         10.81    3.27           32.5      39.0        11.36      5.05
# 3         12.07    3.70           27.0      32.5        17.00     10.80
# 6         11.00    3.22           29.0      34.0         8.00      5.60
# 9         12.15    3.37           31.0      35.5        20.00      9.10
#
#    height_no_shoes  height_shoes  weight  wingspan  ...  three_pointers  \
# 1             70.0         71.75   161.0     76.00  ...           205.0
# 2             79.5         80.75   220.1     83.75  ...            16.0
# 3             84.0         85.75   271.0     87.25  ...             0.0
# 6             74.0         75.50   186.0     78.50  ...           114.0
# 9             80.0         81.75   246.0     84.75  ...             0.0
#
#    total_rebound_percentage  total_rebounds  true_shooting_percentage  \
# 1                       6.6           397.0                     0.565
# 2                      14.9           303.0                     0.503
# 3                      19.4           790.0                     0.565
# 6                       5.7           379.0                     0.551
# 9                      17.0           864.0                     0.601
#
#    turnover_percentage  turnovers  two_point_attempts  two_point_percentage  \
# 1                 18.5      303.0               616.0                 0.479
# 2                 10.5       55.0               337.0                 0.513
# 3                 15.2      176.0               789.0                 0.550
# 6                 16.5      299.0               979.0                 0.502
# 9                 15.6      173.0               720.0                 0.589
#
#    two_pointers  usage_percentage
# 1         295.0              23.2
# 2         173.0              23.2
# 3         434.0              24.9
# 6         491.0              25.3
# 9         424.0              18.6
#
# [5 rows x 39 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_clean, target, random_state = 23)
X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(limit_yrs, target, random_state = 23)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.31521739130434784

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.34782608695652173

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.034731778106937894, 'sprint'),
#  (0.033279002461611834, 'turnover_percentage'),
#  (0.032981000516664916, 'assist_percentage'),
#  (0.03230525688039305, 'personal_fouls'),
#  (0.032114984310762075, 'usage_percentage'),
#  (0.03050694450710742, 'two_point_percentage'),
#  (0.02982076007385844, 'total_rebound_percentage'),
#  (0.02942750380313259, 'free_throw_attempt_rate'),
#  (0.02932764277550598, 'true_shooting_percentage'),
#  (0.029256227200587886, 'offensive_rebounds'),
#  (0.027996430093717963, 'blocks'),
#  (0.027738464222730064, 'defensive_rebounds'),
#  (0.027120221083769727, 'steals'),
#  (0.027045984247682137, 'lane_agility'),
#  (0.02696259625062409, 'assists'),
#  (0.026445961582379558, 'effective_field_goal_percentage'),
#  (0.026073401473327564, 'total_rebounds'),
#  (0.0256467826606525, 'weight'),
#  (0.025587209300919834, 'three_point_percentage'),
#  (0.02532118522846125, 'three_point_attempts'),
#  (0.02470027912027468, 'bench_press'),
#  (0.02457744866152776, 'minutes_played'),
#  (0.02430071107591374, 'body_fat'),
#  (0.02415387474574466, 'free_throw_percentage'),
#  (0.023765699525397237, 'three_pointers'),
#  (0.023275449858229078, 'max_leap'),
#  (0.023077468111699844, 'free_throws'),
#  (0.02300590459469777, 'turnovers'),
#  (0.02271064521492918, 'three_point_attempt_rate'),
#  (0.0222746399969466, 'height_shoes'),
#  (0.021778200991814895, 'wingspan'),
#  (0.02133869590776495, 'free_throw_attempt'),
#  (0.020921142113632576, 'two_point_attempts'),
#  (0.020882557479251992, 'two_pointers'),
#  (0.02078330560091145, 'standing_leap'),
#  (0.020736117528483675, 'height_no_shoes'),
#  (0.01981647281147889, 'field_goal_attempts'),
#  (0.019128535028710536, 'points'),
#  (0.019083514851763822, 'field_goals')]

# %%
df = pd.DataFrame(zip(X_test_full['player'], rf.predict_proba(X_test), rf.predict(X_test)))

df[2].value_counts()
# Out:
# Role Player    55
# Starter        25
# All-Star        6
# Bust            6
# Name: 2, dtype: int64

# %%
for index, row in df.iterrows():
    print(f'Player Name: {row[0]}')
    print(f'Model Prediction: {row[2]}')
    print(f'Probability of Bust: {row[1][1]}')
    print(f'Probability of Role Player: {row[1][2]}')
    print(f'Probability of Starter: {row[1][3]}')
    print(f'Probability of All-Star: {row[1][0]}')
    #print(f'Probability of Role Player or Better: {row[1][0] + row[1][2] + row[1][3]}')
    #print(f'Probability of Starter or Better: {row[1][0] + row[1][3]}')
    #print(f'Probability of All-Star: {row[1][0]}')
    print('----------------------------------------------')
# Out:
# Player Name: Darius Miller
# Model Prediction: Role Player
# Probability of Bust: 0.04
# Probability of Role Player: 0.6
# Probability of Starter: 0.275
# Probability of All-Star: 0.085
# ----------------------------------------------
# Player Name: Quentin Richardson
# Model Prediction: Starter
# Probability of Bust: 0.07
# Probability of Role Player: 0.36
# Probability of Starter: 0.455
# Probability of All-Star: 0.115
# ----------------------------------------------
# Player Name: Mike Scott
# Model Prediction: Role Player
# Probability of Bust: 0.265
# Probability of Role Player: 0.5
# Probability of Starter: 0.145
# Probability of All-Star: 0.09
# ----------------------------------------------
# Player Name: Will Barton
# Model Prediction: All-Star
# Probability of Bust: 0.18
# Probability of Role Player: 0.25
# Probability of Starter: 0.27
# Probability of All-Star: 0.3
# ----------------------------------------------
# Player Name: Andrew Nicholson
# Model Prediction: Bust
# Probability of Bust: 0.425
# Probability of Role Player: 0.26
# Probability of Starter: 0.16
# Probability of All-Star: 0.155
# ----------------------------------------------
# Player Name: Tayshaun Prince
# Model Prediction: Role Player
# Probability of Bust: 0.055
# Probability of Role Player: 0.635
# Probability of Starter: 0.27
# Probability of All-Star: 0.04
# ----------------------------------------------
# Player Name: Jae Crowder
# Model Prediction: Starter
# Probability of Bust: 0.105
# Probability of Role Player: 0.29
# Probability of Starter: 0.37
# Probability of All-Star: 0.235
# ----------------------------------------------
# Player Name: Shabazz Muhammad
# Model Prediction: Starter
# Probability of Bust: 0.14
# Probability of Role Player: 0.22
# Probability of Starter: 0.495
# Probability of All-Star: 0.145
# ----------------------------------------------
# Player Name: Solomon Hill
# Model Prediction: Role Player
# Probability of Bust: 0.07
# Probability of Role Player: 0.565
# Probability of Starter: 0.19
# Probability of All-Star: 0.175
# ----------------------------------------------
# Player Name: Dan Gadzuric
# Model Prediction: Role Player
# Probability of Bust: 0.23
# Probability of Role Player: 0.505
# Probability of Starter: 0.13
# Probability of All-Star: 0.135
# ----------------------------------------------
# Player Name: Norris Cole
# Model Prediction: Bust
# Probability of Bust: 0.365
# Probability of Role Player: 0.235
# Probability of Starter: 0.265
# Probability of All-Star: 0.135
# ----------------------------------------------
# Player Name: Rodney Carney
# Model Prediction: Role Player
# Probability of Bust: 0.11
# Probability of Role Player: 0.55
# Probability of Starter: 0.185
# Probability of All-Star: 0.155
# ----------------------------------------------
# Player Name: Gary Harris
# Model Prediction: Starter
# Probability of Bust: 0.08
# Probability of Role Player: 0.26
# Probability of Starter: 0.525
# Probability of All-Star: 0.135
# ----------------------------------------------
# Player Name: Chris Bosh
# Model Prediction: Role Player
# Probability of Bust: 0.05
# Probability of Role Player: 0.38
# Probability of Starter: 0.235
# Probability of All-Star: 0.335
# ----------------------------------------------
# Player Name: Kevin Martin
# Model Prediction: Starter
# Probability of Bust: 0.085
# Probability of Role Player: 0.34
# Probability of Starter: 0.385
# Probability of All-Star: 0.19
# ----------------------------------------------
# Player Name: Kirk Hinrich
# Model Prediction: Role Player
# Probability of Bust: 0.195
# Probability of Role Player: 0.355
# Probability of Starter: 0.3
# Probability of All-Star: 0.15
# ----------------------------------------------
# Player Name: Dwight Powell
# Model Prediction: Role Player
# Probability of Bust: 0.21
# Probability of Role Player: 0.565
# Probability of Starter: 0.135
# Probability of All-Star: 0.09
# ----------------------------------------------
# Player Name: Darius Songaila
# Model Prediction: Bust
# Probability of Bust: 0.36
# Probability of Role Player: 0.295
# Probability of Starter: 0.24
# Probability of All-Star: 0.105
# ----------------------------------------------
# Player Name: James Johnson
# Model Prediction: Role Player
# Probability of Bust: 0.075
# Probability of Role Player: 0.495
# Probability of Starter: 0.26
# Probability of All-Star: 0.17
# ----------------------------------------------
# Player Name: Steve Blake
# Model Prediction: Starter
# Probability of Bust: 0.225
# Probability of Role Player: 0.245
# Probability of Starter: 0.38
# Probability of All-Star: 0.15
# ----------------------------------------------
# Player Name: Jerryd Bayless
# Model Prediction: Starter
# Probability of Bust: 0.075
# Probability of Role Player: 0.305
# Probability of Starter: 0.39
# Probability of All-Star: 0.23
# ----------------------------------------------
# Player Name: Elfrid Payton
# Model Prediction: Role Player
# Probability of Bust: 0.105
# Probability of Role Player: 0.395
# Probability of Starter: 0.285
# Probability of All-Star: 0.215
# ----------------------------------------------
# Player Name: Tyler Hansbrough
# Model Prediction: Role Player
# Probability of Bust: 0.185
# Probability of Role Player: 0.35
# Probability of Starter: 0.24
# Probability of All-Star: 0.225
# ----------------------------------------------
# Player Name: Wayne Ellington
# Model Prediction: Role Player
# Probability of Bust: 0.035
# Probability of Role Player: 0.535
# Probability of Starter: 0.285
# Probability of All-Star: 0.145
# ----------------------------------------------
# Player Name: Jameer Nelson
# Model Prediction: Role Player
# Probability of Bust: 0.165
# Probability of Role Player: 0.43
# Probability of Starter: 0.315
# Probability of All-Star: 0.09
# ----------------------------------------------
# Player Name: Mario Chalmers
# Model Prediction: Starter
# Probability of Bust: 0.05
# Probability of Role Player: 0.36
# Probability of Starter: 0.44
# Probability of All-Star: 0.15
# ----------------------------------------------
# Player Name: Marvin Williams
# Model Prediction: Role Player
# Probability of Bust: 0.05
# Probability of Role Player: 0.485
# Probability of Starter: 0.3
# Probability of All-Star: 0.165
# ----------------------------------------------
# Player Name: Jared Sullinger
# Model Prediction: Bust
# Probability of Bust: 0.34
# Probability of Role Player: 0.32
# Probability of Starter: 0.165
# Probability of All-Star: 0.175
# ----------------------------------------------
# Player Name: P.J. Tucker
# Model Prediction: Role Player
# Probability of Bust: 0.12
# Probability of Role Player: 0.525
# Probability of Starter: 0.145
# Probability of All-Star: 0.21
# ----------------------------------------------
# Player Name: O.J. Mayo
# Model Prediction: Starter
# Probability of Bust: 0.07
# Probability of Role Player: 0.23
# Probability of Starter: 0.455
# Probability of All-Star: 0.245
# ----------------------------------------------
# Player Name: Jamal Crawford
# Model Prediction: Role Player
# Probability of Bust: 0.055
# Probability of Role Player: 0.425
# Probability of Starter: 0.245
# Probability of All-Star: 0.275
# ----------------------------------------------
# Player Name: Brook Lopez
# Model Prediction: Role Player
# Probability of Bust: 0.24
# Probability of Role Player: 0.365
# Probability of Starter: 0.165
# Probability of All-Star: 0.23
# ----------------------------------------------
# Player Name: Bobby Jones
# Model Prediction: Role Player
# Probability of Bust: 0.115
# Probability of Role Player: 0.595
# Probability of Starter: 0.17
# Probability of All-Star: 0.12
# ----------------------------------------------
# Player Name: Derrick Rose
# Model Prediction: All-Star
# Probability of Bust: 0.09
# Probability of Role Player: 0.19
# Probability of Starter: 0.335
# Probability of All-Star: 0.385
# ----------------------------------------------
# Player Name: T.J. Ford
# Model Prediction: Role Player
# Probability of Bust: 0.23
# Probability of Role Player: 0.34
# Probability of Starter: 0.22
# Probability of All-Star: 0.21
# ----------------------------------------------
# Player Name: Russell Westbrook
# Model Prediction: All-Star
# Probability of Bust: 0.08
# Probability of Role Player: 0.27
# Probability of Starter: 0.32
# Probability of All-Star: 0.33
# ----------------------------------------------
# Player Name: Nik Stauskas
# Model Prediction: Starter
# Probability of Bust: 0.095
# Probability of Role Player: 0.305
# Probability of Starter: 0.405
# Probability of All-Star: 0.195
# ----------------------------------------------
# Player Name: Corey Brewer
# Model Prediction: Role Player
# Probability of Bust: 0.04
# Probability of Role Player: 0.455
# Probability of Starter: 0.34
# Probability of All-Star: 0.165
# ----------------------------------------------
# Player Name: Kentavious Caldwell-Pope
# Model Prediction: Starter
# Probability of Bust: 0.105
# Probability of Role Player: 0.155
# Probability of Starter: 0.555
# Probability of All-Star: 0.185
# ----------------------------------------------
# Player Name: Marcus Fizer
# Model Prediction: Role Player
# Probability of Bust: 0.155
# Probability of Role Player: 0.45
# Probability of Starter: 0.295
# Probability of All-Star: 0.1
# ----------------------------------------------
# Player Name: Nate Robinson
# Model Prediction: Starter
# Probability of Bust: 0.05
# Probability of Role Player: 0.365
# Probability of Starter: 0.395
# Probability of All-Star: 0.19
# ----------------------------------------------
# Player Name: Michael Redd
# Model Prediction: Role Player
# Probability of Bust: 0.185
# Probability of Role Player: 0.49
# Probability of Starter: 0.245
# Probability of All-Star: 0.08
# ----------------------------------------------
# Player Name: DeJuan Blair
# Model Prediction: Role Player
# Probability of Bust: 0.24
# Probability of Role Player: 0.33
# Probability of Starter: 0.2
# Probability of All-Star: 0.23
# ----------------------------------------------
# Player Name: Aaron Gray
# Model Prediction: Role Player
# Probability of Bust: 0.275
# Probability of Role Player: 0.345
# Probability of Starter: 0.135
# Probability of All-Star: 0.245
# ----------------------------------------------
# Player Name: Eddie Griffin
# Model Prediction: Role Player
# Probability of Bust: 0.15
# Probability of Role Player: 0.37
# Probability of Starter: 0.3
# Probability of All-Star: 0.18
# ----------------------------------------------
# Player Name: Kemba Walker
# Model Prediction: Starter
# Probability of Bust: 0.18
# Probability of Role Player: 0.3
# Probability of Starter: 0.32
# Probability of All-Star: 0.2
# ----------------------------------------------
# Player Name: Isaiah Canaan
# Model Prediction: Starter
# Probability of Bust: 0.195
# Probability of Role Player: 0.225
# Probability of Starter: 0.34
# Probability of All-Star: 0.24
# ----------------------------------------------
# Player Name: Archie Goodwin
# Model Prediction: Role Player
# Probability of Bust: 0.11
# Probability of Role Player: 0.34
# Probability of Starter: 0.245
# Probability of All-Star: 0.305
# ----------------------------------------------
# Player Name: Ty Lawson
# Model Prediction: Starter
# Probability of Bust: 0.11
# Probability of Role Player: 0.28
# Probability of Starter: 0.38
# Probability of All-Star: 0.23
# ----------------------------------------------
# Player Name: Luke Walton
# Model Prediction: Role Player
# Probability of Bust: 0.12
# Probability of Role Player: 0.5
# Probability of Starter: 0.265
# Probability of All-Star: 0.115
# ----------------------------------------------
# Player Name: Marcus Williams
# Model Prediction: Bust
# Probability of Bust: 0.665
# Probability of Role Player: 0.14
# Probability of Starter: 0.095
# Probability of All-Star: 0.1
# ----------------------------------------------
# Player Name: Bobby Simmons
# Model Prediction: Role Player
# Probability of Bust: 0.13
# Probability of Role Player: 0.385
# Probability of Starter: 0.345
# Probability of All-Star: 0.14
# ----------------------------------------------
# Player Name: Dahntay Jones
# Model Prediction: Role Player
# Probability of Bust: 0.16
# Probability of Role Player: 0.425
# Probability of Starter: 0.35
# Probability of All-Star: 0.065
# ----------------------------------------------
# Player Name: Eddie House
# Model Prediction: Role Player
# Probability of Bust: 0.18
# Probability of Role Player: 0.475
# Probability of Starter: 0.26
# Probability of All-Star: 0.085
# ----------------------------------------------
# Player Name: Taj Gibson
# Model Prediction: Role Player
# Probability of Bust: 0.29
# Probability of Role Player: 0.335
# Probability of Starter: 0.135
# Probability of All-Star: 0.24
# ----------------------------------------------
# Player Name: Joel Przybilla
# Model Prediction: Role Player
# Probability of Bust: 0.175
# Probability of Role Player: 0.44
# Probability of Starter: 0.21
# Probability of All-Star: 0.175
# ----------------------------------------------
# Player Name: Michael Carter-Williams
# Model Prediction: All-Star
# Probability of Bust: 0.18
# Probability of Role Player: 0.28
# Probability of Starter: 0.16
# Probability of All-Star: 0.38
# ----------------------------------------------
# Player Name: Mo Williams
# Model Prediction: Role Player
# Probability of Bust: 0.09
# Probability of Role Player: 0.43
# Probability of Starter: 0.235
# Probability of All-Star: 0.245
# ----------------------------------------------
# Player Name: Josh Howard
# Model Prediction: Role Player
# Probability of Bust: 0.185
# Probability of Role Player: 0.43
# Probability of Starter: 0.305
# Probability of All-Star: 0.08
# ----------------------------------------------
# Player Name: Kyle Korver
# Model Prediction: Role Player
# Probability of Bust: 0.215
# Probability of Role Player: 0.445
# Probability of Starter: 0.16
# Probability of All-Star: 0.18
# ----------------------------------------------
# Player Name: Hilton Armstrong
# Model Prediction: Role Player
# Probability of Bust: 0.38
# Probability of Role Player: 0.415
# Probability of Starter: 0.095
# Probability of All-Star: 0.11
# ----------------------------------------------
# Player Name: Matt Barnes
# Model Prediction: Role Player
# Probability of Bust: 0.055
# Probability of Role Player: 0.42
# Probability of Starter: 0.28
# Probability of All-Star: 0.245
# ----------------------------------------------
# Player Name: Kosta Koufos
# Model Prediction: Role Player
# Probability of Bust: 0.135
# Probability of Role Player: 0.41
# Probability of Starter: 0.275
# Probability of All-Star: 0.18
# ----------------------------------------------
# Player Name: Carmelo Anthony
# Model Prediction: Starter
# Probability of Bust: 0.1
# Probability of Role Player: 0.155
# Probability of Starter: 0.605
# Probability of All-Star: 0.14
# ----------------------------------------------
# Player Name: Gerald Wallace
# Model Prediction: Role Player
# Probability of Bust: 0.065
# Probability of Role Player: 0.465
# Probability of Starter: 0.255
# Probability of All-Star: 0.215
# ----------------------------------------------
# Player Name: Casey Jacobsen
# Model Prediction: Starter
# Probability of Bust: 0.135
# Probability of Role Player: 0.275
# Probability of Starter: 0.35
# Probability of All-Star: 0.24
# ----------------------------------------------
# Player Name: Shannon Brown
# Model Prediction: Starter
# Probability of Bust: 0.025
# Probability of Role Player: 0.385
# Probability of Starter: 0.46
# Probability of All-Star: 0.13
# ----------------------------------------------
# Player Name: Festus Ezeli
# Model Prediction: Role Player
# Probability of Bust: 0.3
# Probability of Role Player: 0.44
# Probability of Starter: 0.11
# Probability of All-Star: 0.15
# ----------------------------------------------
# Player Name: Joey Graham
# Model Prediction: Role Player
# Probability of Bust: 0.14
# Probability of Role Player: 0.475
# Probability of Starter: 0.225
# Probability of All-Star: 0.16
# ----------------------------------------------
# Player Name: Thaddeus Young
# Model Prediction: Role Player
# Probability of Bust: 0.045
# Probability of Role Player: 0.325
# Probability of Starter: 0.325
# Probability of All-Star: 0.305
# ----------------------------------------------
# Player Name: Jeremy Lamb
# Model Prediction: Starter
# Probability of Bust: 0.04
# Probability of Role Player: 0.31
# Probability of Starter: 0.455
# Probability of All-Star: 0.195
# ----------------------------------------------
# Player Name: Jarvis Hayes
# Model Prediction: Starter
# Probability of Bust: 0.055
# Probability of Role Player: 0.31
# Probability of Starter: 0.52
# Probability of All-Star: 0.115
# ----------------------------------------------
# Player Name: Hassan Whiteside
# Model Prediction: Role Player
# Probability of Bust: 0.13
# Probability of Role Player: 0.39
# Probability of Starter: 0.195
# Probability of All-Star: 0.285
# ----------------------------------------------
# Player Name: Jordan Clarkson
# Model Prediction: Starter
# Probability of Bust: 0.085
# Probability of Role Player: 0.255
# Probability of Starter: 0.425
# Probability of All-Star: 0.235
# ----------------------------------------------
# Player Name: Chandler Parsons
# Model Prediction: Role Player
# Probability of Bust: 0.12
# Probability of Role Player: 0.495
# Probability of Starter: 0.16
# Probability of All-Star: 0.225
# ----------------------------------------------
# Player Name: Jeff Green
# Model Prediction: Role Player
# Probability of Bust: 0.185
# Probability of Role Player: 0.42
# Probability of Starter: 0.255
# Probability of All-Star: 0.14
# ----------------------------------------------
# Player Name: Tony Allen
# Model Prediction: All-Star
# Probability of Bust: 0.015
# Probability of Role Player: 0.28
# Probability of Starter: 0.32
# Probability of All-Star: 0.385
# ----------------------------------------------
# Player Name: Terrence Ross
# Model Prediction: Starter
# Probability of Bust: 0.065
# Probability of Role Player: 0.295
# Probability of Starter: 0.455
# Probability of All-Star: 0.185
# ----------------------------------------------
# Player Name: Cole Aldrich
# Model Prediction: Role Player
# Probability of Bust: 0.2
# Probability of Role Player: 0.415
# Probability of Starter: 0.085
# Probability of All-Star: 0.3
# ----------------------------------------------
# Player Name: Brandan Wright
# Model Prediction: Role Player
# Probability of Bust: 0.11
# Probability of Role Player: 0.34
# Probability of Starter: 0.235
# Probability of All-Star: 0.315
# ----------------------------------------------
# Player Name: Joey Dorsey
# Model Prediction: All-Star
# Probability of Bust: 0.255
# Probability of Role Player: 0.215
# Probability of Starter: 0.215
# Probability of All-Star: 0.315
# ----------------------------------------------
# Player Name: Caron Butler
# Model Prediction: Role Player
# Probability of Bust: 0.17
# Probability of Role Player: 0.385
# Probability of Starter: 0.225
# Probability of All-Star: 0.22
# ----------------------------------------------
# Player Name: Devin Harris
# Model Prediction: Starter
# Probability of Bust: 0.095
# Probability of Role Player: 0.26
# Probability of Starter: 0.47
# Probability of All-Star: 0.175
# ----------------------------------------------
# Player Name: Royal Ivey
# Model Prediction: Role Player
# Probability of Bust: 0.065
# Probability of Role Player: 0.505
# Probability of Starter: 0.235
# Probability of All-Star: 0.195
# ----------------------------------------------
# Player Name: Courtney Alexander
# Model Prediction: Role Player
# Probability of Bust: 0.155
# Probability of Role Player: 0.4
# Probability of Starter: 0.37
# Probability of All-Star: 0.075
# ----------------------------------------------
# Player Name: Darrell Arthur
# Model Prediction: Role Player
# Probability of Bust: 0.155
# Probability of Role Player: 0.57
# Probability of Starter: 0.175
# Probability of All-Star: 0.1
# ----------------------------------------------
# Player Name: Mike Conley
# Model Prediction: Role Player
# Probability of Bust: 0.08
# Probability of Role Player: 0.35
# Probability of Starter: 0.31
# Probability of All-Star: 0.26
# ----------------------------------------------
# Player Name: Jordan Crawford
# Model Prediction: Starter
# Probability of Bust: 0.085
# Probability of Role Player: 0.24
# Probability of Starter: 0.365
# Probability of All-Star: 0.31
# ----------------------------------------------
# Player Name: Josh McRoberts
# Model Prediction: Role Player
# Probability of Bust: 0.14
# Probability of Role Player: 0.52
# Probability of Starter: 0.205
# Probability of All-Star: 0.135
# ----------------------------------------------
# Player Name: Michael Bradley
# Model Prediction: Starter
# Probability of Bust: 0.065
# Probability of Role Player: 0.35
# Probability of Starter: 0.355
# Probability of All-Star: 0.23
# ----------------------------------------------
# Player Name: Xavier Henry
# Model Prediction: Role Player
# Probability of Bust: 0.085
# Probability of Role Player: 0.48
# Probability of Starter: 0.2
# Probability of All-Star: 0.235
# ----------------------------------------------
# Player Name: Etan Thomas
# Model Prediction: Bust
# Probability of Bust: 0.345
# Probability of Role Player: 0.275
# Probability of Starter: 0.05
# Probability of All-Star: 0.33
# ----------------------------------------------
